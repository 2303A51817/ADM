# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51817/ADM/blob/main/data_mining_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.read_csv('/content/employee_data.csv')
print(df)
# Out:
#     Employee_ID   Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.0  108953.0               9.0                   36
# 1          1002  36.0   82995.0               8.0                   59
# 2          1003  29.0   70757.0               2.0                   30
# 3          1004  42.0   39692.0               1.0                   30
# 4          1005  40.0   75758.0               7.0                   54
# 5          1006  44.0  102409.0               7.0                   56
# 6          1007  32.0       NaN               NaN                   59
# 7          1008  32.0   95697.0               5.0                   54
# 8          1009  45.0   67065.0               3.0                   49
# 9          1010  57.0       NaN               8.0                   42
# 10         1011  45.0   41534.0               6.0                   38
# 11         1012   NaN   70397.0               NaN                   32
# ...

# %%
df.describe()
# Out:
#        Employee_ID        Age         Salary  Job_Satisfaction  \
# count     50.00000  45.000000      45.000000         40.000000
# mean    1025.50000  39.177778   72349.200000          5.550000
# std       14.57738  10.869659   26170.218818          2.726414
# min     1001.00000  23.000000   31016.000000          1.000000
# 25%     1013.25000  30.000000   52662.000000          3.000000
# 50%     1025.50000  39.000000   70757.000000          6.000000
# 75%     1037.75000  47.000000   92592.000000          7.000000
# max     1050.00000  59.000000  119812.000000         10.000000
#
#        Work_Hours_Per_Week
# count            50.000000
# mean             44.720000
# std               9.722769
# min              30.000000
# 25%              36.000000
# 50%              46.000000
# 75%              53.750000
# max              59.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          50 non-null     int64
#  1   Age                  45 non-null     float64
#  2   Salary               45 non-null     float64
#  3   Job_Satisfaction     40 non-null     float64
#  4   Work_Hours_Per_Week  50 non-null     int64
# dtypes: float64(3), int64(2)
# memory usage: 2.1 KB

# %%
df.isna()
# Out:
#     Employee_ID    Age  Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0         False  False   False             False                False
# 1         False  False   False             False                False
# 2         False  False   False             False                False
# 3         False  False   False             False                False
# 4         False  False   False             False                False
# 5         False  False   False             False                False
# 6         False  False    True              True                False
# 7         False  False   False             False                False
# 8         False  False   False             False                False
# 9         False  False    True             False                False
# 10        False  False   False             False                False
# 11        False   True   False              True                False
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID             0
# Age                     5
# Salary                  5
# Job_Satisfaction       10
# Work_Hours_Per_Week     0
# dtype: int64

# %%
df['Work_Hours_Per_Week'].mean()

# %%
df['Salary	'].mean()

# %%
df['Salary'].mode()

# %%
df['Work_Hours_Per_Week'].mode()

# %%
df['Job_Satisfaction'].mode()

# %%
df['Job_Satisfaction'].median()

# %%
df['Work_Hours_Per_Week'].median()

# %%
df['Salary'].median()

# %%
df['Job_Satisfaction'] = df['Job_Satisfaction'].fillna(df['Job_Satisfaction'].mean())

# %%
df['Work_Hours_Per_Week'] =df['Work_Hours_Per_Week'].fillna(df['Work_Hours_Per_Week'].mean())

# %%
df['Salary'] =df['Salary'].fillna(df['Salary'].mean())

# %%
df

# %%
print("Dataset after handling missing values:")
print(df)
# Out:
# Dataset after handling missing values:
#     Employee_ID   Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.0  108953.0               9.0                   36
# 1          1002  36.0   82995.0               8.0                   59
# 2          1003  29.0   70757.0               2.0                   30
# 3          1004  42.0   39692.0               1.0                   30
# 4          1005  40.0   75758.0               7.0                   54
# 5          1006  44.0  102409.0               7.0                   56
# 6          1007  32.0       NaN               NaN                   59
# 7          1008  32.0   95697.0               5.0                   54
# 8          1009  45.0   67065.0               3.0                   49
# 9          1010  57.0       NaN               8.0                   42
# 10         1011  45.0   41534.0               6.0                   38
# 11         1012   NaN   70397.0               NaN                   32
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df[['Age', 'Salary']] = scaler.fit_transform(df[['Age', 'Salary']])

# %%
from sklearn.preprocessing import StandardScaler

s_scaler = StandardScaler()

# %%
df[['Job_Satisfaction']] = s_scaler.fit_transform(df[[ 'Job_Satisfaction']])

# %%
df['Job_Satisfaction']
# Out:
# 0      9.0
# 1      8.0
# 2      2.0
# 3      1.0
# 4      7.0
# 5      7.0
# 6      NaN
# 7      5.0
# 8      3.0
# 9      8.0
# 10     6.0
# 11     NaN
# 12     NaN
# 13     1.0
# 14     3.0
# 15     5.0
# 16     3.0
# 17     1.0
# 18     5.0
# 19    10.0
# 20     7.0
# 21     7.0
# 22     NaN
# 23     9.0
# 24    10.0
# 25     NaN
# 26     3.0
# 27     7.0
# 28     1.0
# 29     4.0
# 30     4.0
# 31     NaN
# 32     7.0
# 33     7.0
# 34     NaN
# 35     4.0
# 36     7.0
# 37     NaN
# 38     3.0
# 39     6.0
# 40     2.0
# 41    10.0
# 42     9.0
# 43     5.0
# 44     6.0
# 45     4.0
# 46     NaN
# 47     NaN
# 48     7.0
# 49     9.0
# Name: Job_Satisfaction, dtype: float64

# %%
df[['Work_Hours_Per_Week']] = s_scaler.fit_transform(df[[ 'Work_Hours_Per_Week']])

# %%
df['Work_Hours_Per_Week']
# Out:
# 0     36
# 1     59
# 2     30
# 3     30
# 4     54
# 5     56
# 6     59
# 7     54
# 8     49
# 9     42
# 10    38
# 11    32
# 12    36
# 13    35
# 14    37
# 15    56
# 16    38
# 17    59
# 18    34
# 19    30
# 20    48
# 21    39
# 22    41
# 23    53
# 24    44
# 25    56
# 26    51
# 27    53
# 28    38
# 29    49
# 30    46
# 31    59
# 32    46
# 33    55
# 34    49
# 35    41
# 36    59
# 37    36
# 38    31
# 39    32
# 40    46
# 41    34
# 42    46
# 43    53
# 44    46
# 45    56
# 46    46
# 47    31
# 48    31
# 49    57
# Name: Work_Hours_Per_Week, dtype: int64

# %%
df['Work_Hours_Per_Week'] = (df['Work_Hours_Per_Week'] - df['Work_Hours_Per_Week'].mean()) / df['Work_Hours_Per_Week'].std()

# %%
df
# Out:
#     Employee_ID       Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  0.750000  0.877708               9.0            -0.896864
# 1          1002  0.361111  0.585375               8.0             1.468717
# 2          1003  0.166667  0.447554               2.0            -1.513972
# 3          1004  0.527778  0.097707               1.0            -1.513972
# 4          1005  0.472222  0.503874               7.0             0.954461
# 5          1006  0.583333  0.804011               7.0             1.160163
# 6          1007  0.250000       NaN               NaN             1.468717
# 7          1008  0.250000  0.728422               5.0             0.954461
# 8          1009  0.611111  0.405975               3.0             0.440204
# 9          1010  0.944444       NaN               8.0            -0.279756
# 10         1011  0.611111  0.118451               6.0            -0.691161
# ...

# %%
df['Job_Satisfaction'].mean()
# Out:
# 5.55
